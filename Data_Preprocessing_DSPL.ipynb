# %% [markdown]
# <a href="https://colab.research.google.com/github/DaharaD/Tutorial-7/blob/main/Data_Preprocessing_DSPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/Data preprocessing DSPL/hdx_hapi_food_price_lka (4).csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    location_code        has_hrp        in_gho provider_admin1_name  \
# 0  #country+code  #meta+has_hrp  #meta+in_gho  #adm1+name+provider
# 1            LKA          False         False              Western
# 2            LKA          False         False              Western
# 3            LKA          False         False              Western
# 4            LKA          False         False              Western
#
#   provider_admin2_name admin1_code admin1_name admin2_code admin2_name  \
# 0  #adm2+name+provider  #adm1+code  #adm1+name  #adm2+code  #adm2+name
# 1              Colombo         LK1     Western        LK11     Colombo
# 2              Gampaha         LK1     Western        LK12     Gampaha
# 3              Gampaha         LK1     Western        LK12     Gampaha
# 4              Gampaha         LK1     Western        LK12     Gampaha
#
#   admin_level  ...       lon   commodity_category       commodity_name  \
# ...

# %%
# Understand structure and missing values
df.info()
df.describe(include='all')
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15384 entries, 0 to 15383
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   location_code           15384 non-null  object
#  1   has_hrp                 15384 non-null  object
#  2   in_gho                  15384 non-null  object
#  3   provider_admin1_name    15384 non-null  object
#  4   provider_admin2_name    15384 non-null  object
#  5   admin1_code             15384 non-null  object
#  6   admin1_name             15384 non-null  object
#  7   admin2_code             15384 non-null  object
#  8   admin2_name             15384 non-null  object
#  9   admin_level             15384 non-null  object
#  10  market_name             15384 non-null  object
#  11  lat                     15384 non-null  object
#  12  lon                     15384 non-null  object
#  13  commodity_category      15384 non-null  object
# ...
